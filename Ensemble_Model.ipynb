# %% [markdown]
# HYBRID

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.graphics.api import qqplot
from sklearn.metrics import mean_squared_error as mse
# %matplotlib inline
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = pd.read_csv('/content/newdata.csv')

# %%
data.plot(figsize=(8,8))
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

# %%
percentage = 0.6
series = data['cpu_request'].tolist()
size = int(len(series) * 0.66)
train, test = series[0:size], series[size:len(series)]
model = ARIMA(train , order = (1,0,3))
model_fit = model.fit()

# %%
from statsmodels.tsa.stattools import acf, pacf
acf_1 = acf(series)[1:20]
plt.plot(acf_1)
test_df = pd.DataFrame([acf_1]).T
test_df.columns = ["Pandas Autocorrelation"]
test_df.index += 1
test_df.plot(kind='bar')
pacf_1 = pacf(series)[1:20]
plt.plot(pacf_1)
plt.show()
test_df = pd.DataFrame([pacf_1]).T
test_df.columns = ['Pandas Partial Autocorrelation']
test_df.index += 1
test_df.plot(kind='bar')
#from the figures we conclude that it is an AR process with a lag of 8-9
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from sklearn import preprocessing
from keras.wrappers.scikit_learn import KerasRegressor
from keras.layers.recurrent import LSTM

# %%
predicted1, resid_test = [], []
history = train
for t in range(len(test)):
    model = ARIMA(history, order=(1,0,3))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    resid_test.append(test[t] - output[0])
    predicted1.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
test_resid = []
for i in resid_test:
    test_resid.append(i[0])
error = mean_squared_error(test, predicted1)
print('Test MSE: %.3f' % error)
plt.plot(test)
plt.plot(predicted1, color='red')
plt.show()
# Out:
# predicted=0.437614, expected=0.235540
# predicted=0.293141, expected=0.218740
# predicted=0.265472, expected=0.262480
# predicted=0.282781, expected=0.213390
# predicted=0.258469, expected=0.408090
# predicted=0.372689, expected=0.450830
# predicted=0.410297, expected=0.481110
# predicted=0.437528, expected=0.481110
# predicted=0.439184, expected=0.474880
# predicted=0.435504, expected=0.481110
# predicted=0.438174, expected=0.468650
# predicted=0.430938, expected=0.481110
# predicted=0.437706, expected=0.481110
# predicted=0.438203, expected=0.481110
# predicted=0.438709, expected=0.481110
# predicted=0.438635, expected=0.449310
# predicted=0.419735, expected=0.428000
# predicted=0.404810, expected=0.481110
# predicted=0.433902, expected=0.428000
# predicted=0.405799, expected=0.312390
# predicted=0.335238, expected=0.237420
# predicted=0.280449, expected=0.149940
# predicted=0.219997, expected=0.208110
# predicted=0.247316, expected=0.412480
# predicted=0.371442, expected=0.431140
# ...

# %%
train, test = series[0:size], series[size:len(series)]
model = ARIMA(train, order=(1,0,3))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
#plot the acf for the residuals
acf_1 = acf(model_fit.resid)[1:20]
plt.plot(acf_1)
test_df = pd.DataFrame([acf_1]).T
test_df.columns = ["Pandas Autocorrelation"]
test_df.index += 1
test_df.plot(kind='bar')
#from the acf obtained from the residuals we concule that 
#there is still a nonlinear relationship among the residuals
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                 6600
# Model:                     ARMA(1, 3)   Log Likelihood                6277.162
# Method:                       css-mle   S.D. of innovations              0.093
# Date:                Wed, 01 Jun 2022   AIC                         -12542.324
# Time:                        10:00:34   BIC                         -12501.555
# Sample:                             0   HQIC                        -12528.234
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3473      0.004     96.001      0.000       0.340       0.354
# ar.L1.y        0.7135      0.023     30.397      0.000       0.668       0.760
# ma.L1.y       -0.1202      0.026     -4.589      0.000      -0.172      -0.069
# ...

# %%
window_size = 50
def make_model(window_size):
    model = Sequential()
    model.add(Dense(50, input_dim=window_size,activation="tanh"))
    model.add(Dense(25, activation="tanh"))
    model.add(Dense(1))
    model.add(Activation("linear"))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

    #def make_lstm_model():
#   model = Sequential()
#   model.add(LSTM(
#        input_dim=1,
#        output_dim=50,
#        return_sequences=True))
#   model.add(Dropout(0.2))
#   model.add(LSTM(
#        100,
#        return_sequences=False))
#   model.add(Dropout(0.2))

#   model.add(Dense(
#        output_dim=1))
#   model.add(Activation("linear"))
#   model.compile(loss="mse", optimizer="rmsprop")
#   return model

model = make_model(50)
#lstm_model = make_lstm_model()
min_max_scaler = preprocessing.MinMaxScaler()
train = np.array(train).reshape(-1,1)

train_scaled = min_max_scaler.fit_transform(train) 
#train_scaled=array(train_scaled).reshape(1, -1)

train_X,train_Y = [],[]
for i in range(0 , len(train_scaled) - window_size):
    train_X.append(train_scaled[i:i+window_size])
    train_Y.append(train_scaled[i+window_size])

new_train_X,new_train_Y = [],[]
for i in train_X:
    new_train_X.append(i.reshape(-1))
for i in train_Y:
    new_train_Y.append(i.reshape(-1))
new_train_X = np.array(new_train_X)
new_train_Y = np.array(new_train_Y)
#new_train_X = np.reshape(new_train_X, (new_train_X.shape[0], new_train_X.shape[1], 1))  nb_epoch=500
model.fit(new_train_X,new_train_Y, epochs=50,batch_size=100, validation_split = .05)
# Out:
# Epoch 1/50
# 63/63 [==============================] - 1s 4ms/step - loss: 0.0285 - val_loss: 0.0147
# Epoch 2/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0143 - val_loss: 0.0124
# Epoch 3/50
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0127 - val_loss: 0.0112
# Epoch 4/50
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0121 - val_loss: 0.0112
# Epoch 5/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0115 - val_loss: 0.0118
# Epoch 6/50
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0116 - val_loss: 0.0104
# Epoch 7/50
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0113 - val_loss: 0.0103
# Epoch 8/50
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0112 - val_loss: 0.0101
# Epoch 9/50
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0113 - val_loss: 0.0102
# Epoch 10/50
# ...

# %%
test_extended = train.tolist()[-1*window_size:] + test_resid
test_data = []
for i in test_extended:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
test_data = np.array(test_data).reshape(-1,1)
min_max_scaler = preprocessing.MinMaxScaler()
test_scaled = min_max_scaler.fit_transform(test_data)
test_X,test_Y = [],[]
for i in range(0 , len(test_scaled) - window_size):
    test_X.append(test_scaled[i:i+window_size])
    test_Y.append(test_scaled[i+window_size])
    new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)
#new_test_X = np.reshape(new_test_X, (new_test_X.shape[0], new_test_X.shape[1], 1))
predictions = model.predict(new_train_X)
predictions_rescaled=min_max_scaler.inverse_transform(predictions)
Y = pd.DataFrame(new_train_Y)
pred = pd.DataFrame(predictions)
plt.plot(Y)
plt.plot(pred , color = 'r')
#p.plot()
plt.show()
predictions_rescaled=idx = (-predictions_rescaled).argsort()[:3400]
error = mse(test_resid,predictions_rescaled)
print('Test MSE: %.3f' % error)
# Out:
# Test MSE: 0.009

# %%
pred_final = predictions_rescaled + predicted1
error = mse(test,pred_final)
print('Test MSE: %.3f' % error)
# Out:
# Test MSE: 0.009

# %%
Y = pd.DataFrame(test)
pred = pd.DataFrame(pred_final)
plt.plot(Y)
plt.plot(pred , color = 'r')
#p.plot()
plt.show()

# %%
predictions = pd.DataFrame(test)
y_pred = pred_final
predictions['mid'] = y_pred
predictions.head()


plt.figure(figsize=(20,17))
plt.style.use('seaborn-poster')
plt.subplot(2,1,1)
#plt.plot(predictions[0][0:100])
plt.plot(predictions[0], label='Actual value')
plt.plot(predictions['mid'],label='Predicted value',color='r')
x_ticks = [0,500,1000,1500,2000,2500,3000,3500]

#specify x-axis labels
x_labels = ['May 1 ,2019', 'May 6,2019 ', 'May 11,2019', 'May 16,2019', 'May 21,2019','May 26,2019','May 31,2019'] 

#add x-axis values to plot
plt.xticks(ticks=x_ticks, labels=x_labels)
plt.ylabel('Mean CPU request')
plt.xlabel('Time Stamp')
plt.title('Test Data')
plt.legend()

plt.subplot(2,1,2)
plt.plot(predictions[0].tail(100), label='Actual value',color='green')
plt.plot(predictions['mid'].tail(100), label='Predicted value',color='red')
x_ticks = [3300,3320,3340,3360,3380]
x_labels = ['May 21,17:00', 'May 22,13:00 ', 'May 23,09:00', 'May 24,05:00', 'May 25,01:00']
plt.xticks(ticks=x_ticks, labels=x_labels)
plt.ylabel('Mean cpu request')
plt.xlabel('Time Stamp')
plt.title('Test Data - Zoom View')
plt.legend();

# %%
d1 = pd.DataFrame(pred_final, columns = ['Predicted_CPU_Request'])
print(d1)
# Out:
#       Predicted_CPU_Request
# 0                  0.437614
# 1                  0.293141
# 2                  0.265472
# 3                  0.282781
# 4                  0.258469
# ...                     ...
# 3395               0.369316
# 3396               0.407491
# 3397               0.338997
# 3398               0.366291
# 3399               0.392904
#
# [3400 rows x 1 columns]

# %%
d2 = pd.DataFrame(test, columns = ['Existing_CPU_Request'])
print(d2)
# Out:
#       Existing_CPU_Request
# 0                 0.235540
# 1                 0.218740
# 2                 0.262480
# 3                 0.213390
# 4                 0.408090
# ...                    ...
# 3395              0.449960
# 3396              0.318766
# 3397              0.381855
# 3398              0.425040
# 3399              0.437500
#
# [3400 rows x 1 columns]

# %% [markdown]
# ELM

# %%
import pandas as pd
from pandas import datetime
def parser(x):
    return datetime.strptime(x,"%d-%m-%Y %H:%M")
data1 = pd.read_csv('/content/newdata.csv', header = 0, parse_dates=[0],index_col=0,squeeze=True, date_parser=parser)
data1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
# timestamp
# 2019-05-01 19:00:00    0.250000
# 2019-05-01 19:01:00    0.328090
# 2019-05-01 19:02:00    0.237440
# 2019-05-01 19:03:00    0.224980
# 2019-05-01 19:04:00    0.196928
#                          ...
# 2019-05-08 17:35:00    0.449960
# 2019-05-08 17:36:00    0.318766
# 2019-05-08 17:37:00    0.381855
# 2019-05-08 17:38:00    0.425040
# 2019-05-08 17:39:00    0.437500
# Name: cpu_request, Length: 10000, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data1 = data1.astype(float)
data1
data1.plot(style='k.',ylabel='CPU request')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
import math
import numpy as np
from scipy.linalg import pinv2
data1 = np.array(data1)
data1 = np.reshape(data1, (-1, 1))
data1
# Out:
# array([[0.25     ],
#        [0.32809  ],
#        [0.23744  ],
#        ...,
#        [0.3818547],
#        [0.42504  ],
#        [0.4375   ]])

# %%
m = 14
per = (1736 - m)/1826
size = int(len(data1) * per)
d_train, d_test = data1[0:size], data1[size:len(data1)]
mean_train = np.mean(d_train)
sd_train = np.std(d_train)
d_train = (d_train-mean_train)/sd_train
d_test = (d_test-mean_train)/sd_train

# %%
X_train = np.array([d_train[i][0] for i in range(m)])
y_train = np.array(d_train[m][0])
for i in range(1,(d_train.shape[0]-m)):
    l = np.array([d_train[j][0] for j in range(i,i+m)])
    X_train = np.vstack([X_train,l])
    y_train = np.vstack([y_train,d_train[i+m]])
X_test = np.array([d_test[i][0] for i in range(m)])
y_test = np.array(d_test[m][0])
for i in range(1,(d_test.shape[0]-m)):
    l = np.array([d_test[j][0] for j in range(i,i+m)])
    X_test = np.vstack([X_test,l])
    y_test = np.vstack([y_test,d_test[i+m]])
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
#> (1708, 14)
#> (1708, 1)
#> (90, 14)
#> (90, 1)
# Out:
# (9416, 14)
# (9416, 1)
# (556, 14)
# (556, 1)

# %%
import scipy.stats as stats
input_size = X_train.shape[1]
hidden_size = 500  #no. of hidden neurons
mu, sigma = 0, 1
w_lo = -1 
w_hi = 1
b_lo = -1 
b_hi = 1
#initialising input weights and biases randomly drawn from a truncated normal distribution
input_weights = stats.truncnorm.rvs((w_lo - mu) / sigma, (w_hi - mu) / sigma, loc=mu, scale=sigma,size=[input_size,hidden_size])
biases = stats.truncnorm.rvs((b_lo - mu) / sigma, (b_hi - mu) / sigma, loc=mu, scale=sigma,size=[hidden_size])
def relu(x):      #hidden layer activation function
    return np.maximum(x, 0, x)

# %%
def hidden_nodes(X):
    G = np.dot(X, input_weights)
    G = G + biases
    H = relu(G)
    return H
output_weights = np.dot(pinv2(hidden_nodes(X_train)), y_train)
def predict(X):
    out = hidden_nodes(X)
    out = np.dot(out, output_weights)
    return out
prediction = predict(X_test)

# %%
print(prediction)
# Out:
# [[ 2.86724812e-01]
#  [-2.84805609e-01]
#  [-8.08689918e-01]
#  [-9.38340702e-01]
#  [-1.03136439e+00]
#  [-9.83865616e-01]
#  [-5.32666171e-01]
#  [-5.86543154e-01]
#  [-6.42701839e-01]
#  [-6.47271643e-01]
#  [-1.05457749e+00]
#  [-4.34704545e-01]
#  [-5.05529523e-01]
#  [-4.18898247e-01]
#  [-4.78775642e-01]
#  [ 2.40197994e-01]
#  [ 2.72143945e-01]
#  [ 1.39214952e-01]
#  [ 4.25861428e-01]
#  [ 4.26921350e-01]
#  [-3.54234153e-01]
#  [-1.74397915e-01]
#  [-2.18856940e-01]
#  [-2.40443122e-01]
#  [-2.97253887e-01]
#  [-6.25736314e-01]
#  [-4.34922211e-01]
#  [-7.62032035e-01]
#  [-2.76952187e-01]
#  [-9.03633869e-01]
#  [-8.01983797e-01]
#  [-3.78726293e-01]
#  [-6.00980003e-01]
#  [ 3.51130714e-01]
#  [ 1.80422981e-01]
#  [-4.91444779e-01]
#  [-7.01384197e-01]
#  [-4.59605085e-01]
#  [-7.60149372e-01]
#  [-4.57732355e-01]
#  [ 4.28328130e-02]
#  [-3.78091067e-01]
#  [-9.01566442e-01]
#  [-2.75832897e-01]
#  [ 2.35201559e-01]
#  [ 4.77519879e-01]
#  [ 2.42342029e-01]
# ...

# %%
correct = 0
total = X_test.shape[0]
y_test = (y_test*sd_train) + mean_train
prediction = (prediction*sd_train) + mean_train
# evaluate forecasts
rmse = math.sqrt(mean_squared_error(y_test, prediction))
print('Test RMSE: %.9f' % rmse)
from statistics import *
NRMSE = rmse/mean (prediction.flatten())
print('Test NRMSE: %.9f' % NRMSE)
se=mean_squared_error(y_test, prediction)
print('test MSE: %.9f' % se)
from sklearn.metrics import r2_score
r=r2_score(y_test, prediction)
print('test R2 score: %.9f' % r)
mape_sum = 0
for i,j in zip(y_test,prediction):
    mape_sum = mape_sum + (abs((i-j)/i))
mape = (mape_sum/total)*100
mpe_sum = 0
for i,j in zip(y_test,prediction):
    mpe_sum = mpe_sum + ((i-j)/i)
mpe = (mpe_sum/total)*100
print('Test MAPE: %.3f' % mape)
print('Test MPE: %.3f' % mpe)
# Out:
# Test RMSE: 0.102560820
# Test NRMSE: 0.308380833
# test MSE: 0.010518722
# test R2 score: 0.218763575
# Test MAPE: 29.706
# Test MPE: -10.818

# %%
# plot forecasts against actual outcomes
fig, ax = plt.subplots(figsize = (10,6))
ax.plot(y_test,label = 'Actual')
ax.plot(prediction, color='red',label = 'Predicted')
x_ticks = [0,100,200,300,400,500]
x_labels = ['May 1 ,2019', 'May 6,2019 ', 'May 11,2019', 'May 16,2019', 'May 21,2019','May 26,2019','May 31,2019'] 
plt.xticks(ticks=x_ticks,fontsize = 12, labels=x_labels)
ax.legend(loc='upper right', frameon=False)
plt.xlabel('TIMESTAMP')
plt.ylabel('CPU REQUEST')
plt.title('Forecasting with ELM ')
#plt.xticks([0,20,40,60,80],['2017-10-02','2017-10-22','2017-11-11','2017-12-01','2017-12-21'],fontname="Arial", fontsize = 20, style='italic')
#plt.yticks(fontname="Arial", fontsize = 22, style='italic')
# Out:
# Text(0.5, 1.0, 'Forecasting with ELM ')

# %%
predictions = pd.DataFrame(y_test)
y_pred = prediction
predictions['mid'] = y_pred
predictions.head()


plt.figure(figsize=(20,17))
plt.style.use('seaborn-poster')
plt.subplot(2,1,1)
#plt.plot(predictions[0][0:100])
plt.plot(predictions[0], label='Truth')
plt.plot(predictions['mid'],label='Predict, EXTREME LEARNING MACHINE')
x_ticks = [0,100,200,300,400,500]
x_labels = ['May 1 ,2019', 'May 6,2019 ', 'May 11,2019', 'May 16,2019', 'May 21,2019','May 26,2019','May 31,2019'] 
plt.xticks(ticks=x_ticks,fontsize = 12, labels=x_labels)
plt.ylabel('Mean CPU request')
plt.xlabel('Time Step')
plt.title('Test Data')
plt.legend()

plt.subplot(2,1,2)
plt.plot(predictions[0].tail(100), label='Truth')
plt.plot(predictions['mid'].tail(100), label='Predicted, EXTREME LEARNING MACHINE')
x_ticks = [460,480,500,520,540]
x_labels = ['May 21,17:00', 'May 22,13:00 ', 'May 23,09:00', 'May 24,05:00', 'May 25,01:00']
plt.xticks(ticks=x_ticks, labels=x_labels)
plt.ylabel('Mean cpu request')
plt.xlabel('Time Step')
plt.title('Test Data - Zoom View')
plt.legend();

# %%
d3 = pd.DataFrame(prediction, columns = ['Predicted_CPU_Request'])
print(d3)
# Out:
#      Predicted_CPU_Request
# 0                 0.378830
# 1                 0.308684
# 2                 0.244386
# 3                 0.228473
# 4                 0.217056
# ..                     ...
# 551               0.378231
# 552               0.398705
# 553               0.316858
# 554               0.352508
# 555               0.362908
#
# [556 rows x 1 columns]

# %%
d4 = pd.DataFrame(y_test, columns = ['Existing_CPU_Request'])
print(d4)
# Out:
#      Existing_CPU_Request
# 0                0.271890
# 1                0.187480
# 2                0.199400
# 3                0.096846
# 4                0.137450
# ..                    ...
# 551              0.449960
# 552              0.318766
# 553              0.381855
# 554              0.425040
# 555              0.437500
#
# [556 rows x 1 columns]

# %% [markdown]
# **ENSEMBLE BUILDING**

# %% [markdown]
# METHOD1: AVERAGING

# %%
total=(d1+d3)/2

#averaging
mse=mean_squared_error(d2.head(555),total.head(555))
print('Test MSE: %.9f' % mse)
#root mean squared error 
from sklearn.metrics import mean_squared_error
from math import sqrt
print('Test RMSE')
print(sqrt(mean_squared_error(d2.head(555),total.head(555))))
#Normalized root mean square deviation
from statistics import *
RMSE=sqrt(mean_squared_error(d2.head(555),total.head(555)))
NRMSE = RMSE/mean (pred_final.flatten())
print('Test NRMSE')
print(NRMSE)
#r2 score
from sklearn.metrics import r2_score
print('Test R2 Score')

r=r2_score(d2.head(555),total.head(555))
print(r)
#mean absolute error
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(d2.head(555),total.head(555))
print('Test MAE: %.3f' % mae)
mape = mean_absolute_error(d2.head(555),total.head(555))*100
print('Test MAPE')
print(mape)
# Out:
# Test MSE: 0.011167443
# Test RMSE
# 0.10567612189230959
# Test NRMSE
# 0.3124348349513677
# Test R2 Score
# 0.2381163390095532
# Test MAE: 0.087
# Test MAPE
# 8.748675907585806

# %% [markdown]
# METHOD 2: WEIGHTED AVERAGE

# %%
total1=((d1*2)+d3)/3
#weighted averaging
mse=mean_squared_error(d2.head(555),total1.head(555))
print('Test MSE: %.9f' % mse)
#root mean squared error 
from sklearn.metrics import mean_squared_error
from math import sqrt
print('Test RMSE')
print(sqrt(mean_squared_error(d2.head(555),total1.head(555))))
#Normalized root mean square deviation
from statistics import *
RMSE=sqrt(mean_squared_error(d2.head(555),total1.head(555)))
NRMSE = RMSE/mean (pred_final.flatten())
print('Test NRMSE')
print(NRMSE)
#r2 score
from sklearn.metrics import r2_score
print('Test R2 Score')

r=r2_score(d2.head(555),total1.head(555))
print(r)
#mean absolute error
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(d2.head(555),total1.head(555))
print('Test MAE: %.3f' % mae)
mape = mean_absolute_error(d2.head(555),total1.head(555))*100
print('Test MAPE')
print(mape)
# Out:
# Test MSE: 0.009553748
# Test RMSE
# 0.09774327440255552
# Test NRMSE
# 0.28898111757629763
# Test R2 Score
# 0.348208498795346
# Test MAE: 0.080
# Test MAPE
# 8.014895078386628

# %% [markdown]
# METHOD 3: RANK AVERAGE

# %%
total2=((d1*0.667)+(d3*0.33))

#rank  averaging
mse=mean_squared_error(d2.head(555),total2.head(555))
print('Test MSE: %.9f' % mse)
#root mean squared error 
from sklearn.metrics import mean_squared_error
from math import sqrt
print('Test RMSE')
print(sqrt(mean_squared_error(d2.head(555),total2.head(555))))
#Normalized root mean square deviation
from statistics import *
RMSE=sqrt(mean_squared_error(d2.head(555),total2.head(555)))
NRMSE = RMSE/mean (pred_final.flatten())
print('Test NRMSE')
print(NRMSE)
#r2 score
from sklearn.metrics import r2_score
print('Test R2 Score')

R=r2_score(d2.head(555),total2.head(555))
print(R)
#mean absolute error
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(d2.head(555),total2.head(555))
print('Test MAE: %.3f' % mae)
mape = mean_absolute_error(d2.head(555),total2.head(555))*100
print('Test MAPE')
print(mape)
# Out:
# Test MSE: 0.009557027
# Test RMSE
# 0.0977600481606531
# Test NRMSE
# 0.2890307097287053
# Test R2 Score
# 0.34798477125714955
# Test MAE: 0.080
# Test MAPE
# 8.028630615086058

# %%
import numpy as np
import matplotlib.pyplot as plt

# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))

# set height of bar
MSE = [ 0.011519193,0.009772854,0.009773329]
RMSE = [0.10732750529265339,0.09885774783811174,0.09886014939425712]
#NRMSE = [0.2962772976216345, 0.2682452341130227, 0.2683164117751036]
MAE=[0.089,0.081,0.081]
#MAPE=[8.685375130235528,7.8600309822434795,7.87821087801840]

# Set position of bar on X axis
br1 = np.arange(len(MSE))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
#br4 = [x + barWidth for x in br3]
#br5 = [x + barWidth for x in br4]

# Make the plot
plt.bar(br1, MSE, color ='r', width = barWidth,
		edgecolor ='grey', label ='MSE')
plt.bar(br2, RMSE, color ='g', width = barWidth,
		edgecolor ='grey', label ='RMSE')
plt.bar(br3, MAE, color ='b', width = barWidth,
		edgecolor ='grey', label ='MAE')
#plt.bar(br4, MAE, color ='y', width = barWidth,
		#edgecolor ='grey', label ='MAE')
#plt.bar(br3, MAPE, color ='r', width = barWidth,
		#edgecolor ='grey', label ='MAPE')


# Adding Xticks
plt.xlabel('Ensemble models', fontweight ='bold', fontsize = 15)
plt.ylabel('Perfromance scores', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(MSE))],
		['M1', 'M2', 'M3'])

plt.legend()
plt.show()

# %%
predictions = pd.DataFrame(y_test)
y_pred = prediction
predictions['mid'] = y_pred
predictions.head()


plt.figure(figsize=(20,17))
plt.style.use('seaborn-poster')
plt.subplot(2,1,1)
#plt.plot(predictions[0][0:100])
plt.plot(predictions[0],  label='Actual data')
plt.plot(predictions['mid'], color = 'orange',label='Predicted data-Ensemble Model')
x_ticks = [0,100,200,300,400,500]
x_labels = ['May 1 ,2019', 'May 6,2019 ', 'May 11,2019', 'May 16,2019', 'May 21,2019','May 26,2019','May 31,2019'] 
plt.xticks(ticks=x_ticks,fontsize = 12, labels=x_labels)
plt.ylabel('Mean CPU request')
plt.xlabel('Time Stamp')
plt.title('Test Data')
plt.legend()

# %%
ensem= pd.concat([total1, d4], axis=1, join='inner')
display(ensem)
# Out:
#      Predicted_CPU_Request  Existing_CPU_Request
# 0                 0.418019              0.271890
# 1                 0.298322              0.187480
# 2                 0.258443              0.199400
# 3                 0.264678              0.096846
# 4                 0.244665              0.137450
# ..                     ...                   ...
# 551               0.367233              0.449960
# 552               0.364033              0.318766
# 553               0.314819              0.381855
# 554               0.359366              0.425040
# 555               0.351909              0.437500
#
# [556 rows x 2 columns]

# %%
ensem['Val_Diff'] = ensem['Predicted_CPU_Request'] - ensem['Existing_CPU_Request']

# %%
display(ensem)
# Out:
#      Predicted_CPU_Request  Existing_CPU_Request  Val_Diff
# 0                 0.418019              0.271890  0.146129
# 1                 0.298322              0.187480  0.110842
# 2                 0.258443              0.199400  0.059043
# 3                 0.264678              0.096846  0.167832
# 4                 0.244665              0.137450  0.107215
# ..                     ...                   ...       ...
# 551               0.367233              0.449960 -0.082727
# 552               0.364033              0.318766  0.045267
# 553               0.314819              0.381855 -0.067036
# 554               0.359366              0.425040 -0.065674
# 555               0.351909              0.437500 -0.085591
#
# [556 rows x 3 columns]

# %%
#DECISION MANAGER- whether resource allocation is required or not 
ensem.loc[ensem['Val_Diff'] <= (0.2*ensem['Existing_CPU_Request']), 'Resource_allocation_required'] = 'No'
ensem.loc[ensem['Val_Diff'] >= (0.2*ensem['Existing_CPU_Request']), 'Resource_allocation_required'] = 'Yes'

# %%
display(ensem)
# Out:
#      Predicted_CPU_Request  Existing_CPU_Request  Val_Diff  \
# 0                 0.418019              0.271890  0.146129
# 1                 0.298322              0.187480  0.110842
# 2                 0.258443              0.199400  0.059043
# 3                 0.264678              0.096846  0.167832
# 4                 0.244665              0.137450  0.107215
# ..                     ...                   ...       ...
# 551               0.367233              0.449960 -0.082727
# 552               0.364033              0.318766  0.045267
# 553               0.314819              0.381855 -0.067036
# 554               0.359366              0.425040 -0.065674
# 555               0.351909              0.437500 -0.085591
#
#     Resource_allocation_required
# 0                            Yes
# 1                            Yes
# 2                            Yes
# 3                            Yes
# 4                            Yes
# ..                           ...
# ...
